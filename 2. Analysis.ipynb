# %% [markdown]
# Kaggle link : https://www.kaggle.com/chicago/chicago-contracts

# %% [markdown]
#     Chicago contract 1n contract

# %% [markdown]
# ### Content
# -------------------------------------
# -------------------------------------
#
# <p> Contracts and modifications awarded by the City of Chicago since 1993. This data is currently maintained in the City’s Financial Management and Purchasing System (FMPS), which is used throughout the City for contract management and payment. </p>
#
# **Legacy System Records: Purchase Order/Contract Numbers that begin with alpha characters identify records imported from legacy systems. Records with a null value in the Contract Type field were imported from legacy systems.**
#
# "Comptroller-Other" Contract Type: Some records where the Contract Type is "COMPTROLLER-OTHER" are ordinance-based agreements and may have start dates earlier than 1993.
# Depends Upon Requirements Contracts: If the contract Award Amount is $0, the contract is not cancelled, and the contract is a blanket contract, then the contract award total Depends Upon Requirements. A Depends Upon Requirements contract is an indefinite quantities contract in which the City places orders as needed and the vendor is not guaranteed any particular contract award amount.
#
# Blanket vs. Standard Contracts: Only blanket contracts (contracts for repeated purchases) have FMPS end dates. Standard contracts (for example, construction contracts) terminate upon completion and acceptance of all deliverables. These dates are tracked outside of FMPS.
#
# Negative Modifications: Some contracts are modified to delete scope and money from a contract. These reductions are indicated by negative numbers in the Award Amount field of this dataset.
#
# Data Owner: Procurement Services.
# Time Period: 1993 to present.
# Frequency: Data is updated daily.

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('2. Data/contracts.csv')
# Out:
# /Users/abbi163/opt/anaconda3/envs/sdg/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (2,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#                           Purchase Order Description  \
# 0  DFSS-CORP-YS-CJI: CORP - YOUTH SERVICES - COMM...
# 1  DFSS-ECBG-CS-PISS: PREVENTION INITIATIVE SUPPO...
# 2  700819: INDUSTRIAL EQUIPMENT, TOOLS, ATTACHMEN...
# 3                                   LEASE / L-14121C
# 4  Grant Agreement, YOCM Documentary Grant, Urban...
#
#   Purchase Order (Contract) Number Revision Number Specification Number  \
# 0                            77041               2               774638
# 1                           106913               1               466260
# 2                           117383               0               700819
# 3                            30418              67               125804
# 4                           117399               0              1193898
#
#           Contract Type               Start Date                 End Date  \
# 0       DELEGATE AGENCY  2018-04-01T00:00:00.000  2020-12-31T00:00:00.000
# 1       DELEGATE AGENCY  2019-07-01T00:00:00.000  2020-06-30T00:00:00.000
# 2  COMMODITIES-AVIATION                      NaN                      NaN
# 3        PROPERTY LEASE                      NaN                      NaN
# 4     COMPTROLLER-OTHER  2019-10-28T00:00:00.000  2020-10-28T00:00:00.000
#
#              Approval Date                           Department  \
# 0  2019-12-03T00:00:00.000  DEPT OF FAMILY AND SUPPORT SERVICES
# 1  2019-12-03T00:00:00.000  DEPT OF FAMILY AND SUPPORT SERVICES
# 2  2019-12-03T00:00:00.000       DEPARTMENT OF WATER MANAGEMENT
# 3  2019-12-03T00:00:00.000                                  NaN
# 4  2019-12-03T00:00:00.000       DEPARTMENT OF CULTURAL AFFAIRS
#
#                       Vendor Name  Vendor ID                   Address 1  \
# 0   CHICAGO URBAN LEAGUE DEV CORP  31311292X  4510 S MICHIGAN AVENUE EFT
# 1     CENTERS FOR NEW HORIZONS 01  15427701H       4150 S KING DRIVE EFT
# 2        MSC INDUSTRIAL SUPPLY CO  95881790V                DEPT CH 0075
# 3  30 NORTH. LASALLE PARTNERS LLC  61322110A   30 N LA SALLE ST STE 1420
# 4                  URBAN GATEWAYS  22311188X  205 W RANDOLPH ST STE 1700
#
#                    Address 2      City State         Zip  Award Amount  \
# 0                        NaN   CHICAGO    IL  60653-3898      150000.0
# 1                        NaN   CHICAGO    IL       60653           0.0
# 2                        NaN  PALATINE    IL  60155-0075        1263.0
# 3  30 N LA SALLE ST STE 1420   CHICAGO    IL       60602        3600.0
# 4                        NaN   CHICAGO    IL       60606        6300.0
#
#   Procurement Type Contract PDF
# 0              NaN          NaN
# 1              NaN          NaN
# 2              NaN          NaN
# 3              NaN          NaN
# 4              NaN          NaN
