# %% [markdown]
# ### World bank major contract !!
#
# Kaggle link : https://www.kaggle.com/theworldbank/world-banks-major-contracts

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('1. Data/Major_Contract_Awards.csv')

# %%
df.columns
# Out:
# Index(['As of Date', 'Fiscal Year', 'Region', 'Borrower Country',
#        'Borrower Country Code', 'Project ID', 'Project Name',
#        'Procurement Type', 'Procurement Category', 'Procurement Method',
#        'Product line', 'Major Sector', 'WB Contract Number',
#        'Contract Description', 'Contract Signing Date', 'Supplier',
#        'Supplier Country', 'Supplier Country Code',
#        'Total Contract Amount (USD)', 'Borrower Contract Reference Number'],
#       dtype='object')

# %%
df.head()
# Out:
#                As of Date  Fiscal Year                 Region  \
# 0  09/06/2017 12:00:00 AM         2004                 AFRICA
# 1  09/06/2017 12:00:00 AM         2004                 AFRICA
# 2  09/06/2017 12:00:00 AM         2004                 AFRICA
# 3  09/06/2017 12:00:00 AM         2004                 AFRICA
# 4  09/06/2017 12:00:00 AM         2004  EAST ASIA AND PACIFIC
#
#   Borrower Country Borrower Country Code Project ID  \
# 0             Mali                    ML    P041723
# 1             Mali                    ML    P041723
# 2             Mali                    ML    P041723
# 3             Mali                    ML    P041723
# 4        Indonesia                    ID    P040528
#
#                      Project Name     Procurement Type Procurement Category  \
# 0  Rural Infrastr (FY00) - (PNIR)  Feasibility Studies  CONSULTANT SERVICES
# 1  Rural Infrastr (FY00) - (PNIR)  Feasibility Studies  CONSULTANT SERVICES
# ...
